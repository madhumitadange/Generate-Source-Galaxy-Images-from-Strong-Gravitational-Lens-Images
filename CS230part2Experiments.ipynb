# %% [markdown]
# <a href="https://colab.research.google.com/github/madhumitadange/Generate-Source-Galaxy-Images-from-Strong-Gravitational-Lens-Images/blob/main/CS230part2Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strong Gravitatial Lensing : Generate Original galaxy image using U-Net

# %% [markdown]
# ![Part2.PNG](data:image/png;base64,...)

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from keras.preprocessing import image
from tqdm import tqdm
import zipfile
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import os
import sys
import random
import warnings
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input,BatchNormalization,Activation
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from skimage.metrics import structural_similarity as ssim,peak_signal_noise_ratio as psnr,mean_squared_error as mse

# %% [markdown]
# Read Data created by lenstronamy. Details about Preproccessing, data augmentation, test train, dev split etc in another Notebook

# %%
zip_ref = zipfile.ZipFile("/content/drive/My Drive/CS230/ProjectData.zip", 'r')
zip_ref.extractall("/CS230")
zip_ref.close()

# %% [markdown]
# #Helper Function to plot Lensed and Unlensed images
# Ref: https://github.com/JelleAalbers/minilensmaker/tree/main/minilensmaker

# %%
def exporter():
    """Export utility modified from https://stackoverflow.com/a/41895194
    Returns export decorator, __all__ list
    """
    all_ = []

    def decorator(obj):
        all_.append(obj.__name__)
        return obj

    return decorator, all_


export, __all__ = exporter()
__all__.append("exporter")


@export
def image_grid(
    shape,
    pixel_width,
    x0=0,
    y0=0,
    edges=True,
):
    nx, ny = shape
    dx = nx * pixel_width
    dy = nx * pixel_width
    extra = 1 if edges else 0
    x = np.linspace(-dx / 2, dx / 2, nx + extra) + x0
    y = np.linspace(-dy / 2, dy / 2, ny + extra) + y0
    return x, y


@export
def plot_image(
    img,
    pixel_width,
    log_scale=True,
    label="HST F814W",
    colorbar=True,
    adjust_ax=True,
    vmin=None,
    vmax=None,
    **kwargs
):

    # Set reasonable defaults
    if vmax is None:
        vmax = img.max()
    if vmin is None:
        if log_scale:
            vmin = vmax * 1e-3
        else:
            vmin = img.min()
    kwargs.setdefault(
        "norm",
        matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax)
        if log_scale
        else matplotlib.colors.Normalize(vmin=vmin, vmax=vmax),
    )
    kwargs.setdefault("cmap", "magma")

    # Plot image, note transposition
    plt.pcolormesh(
        *image_grid(img.shape, pixel_width), img.clip(vmin, None).T, **kwargs
    )
    if adjust_ax:
        plt.gca().set_aspect("equal")

    if colorbar:
        # Plot colorbar
        cbar = plt.colorbar(label=label, extend="both")
        cax = cbar.ax
        # Format colobar ticks as scalars (not 10^x)
        cax.yaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter("%g"))
        if len(cbar.get_ticks()) < 2:
            # If there are very few colorbar ticks, show minor ticks too
            cax.yaxis.set_minor_formatter(matplotlib.ticker.FormatStrFormatter("%g"))
            cax.tick_params(axis="y", labelsize=7, which="minor")

    plt.xlabel("[Arcseconds]")
    plt.ylabel("[Arcseconds]")


@export
def draw_box(x, y, **kwargs):
    """Draw rectangle, given x-y boundary tuples"""
    plt.gca().add_patch(
        matplotlib.patches.Rectangle(
            (x[0], y[0]), x[1] - x[0], y[1] - y[0], facecolor="none", **kwargs
        )
    )#

# %%
from skimage import measure
def compare_images(target, ref):
    target = np.squeeze(target/255)
    ref = np.squeeze(ref/255)
    scores = []
    scores.append(psnr(target, ref))
    scores.append(mse(target, ref))
    scores.append(ssim(target, ref, multichannel=True))
    return scores
# Loss functtion
def ssim_loss(y_true, y_pred):
  return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))
def psnr_loss(y_true, y_pred):
  return tf.image.psnr(y_true, y_pred, 1.0)
def mse_ssim_loss(y_true, y_pred):
  return tf.reduce_mean(tf.math.squared_difference(y_true, y_pred)) + 1- tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

# %%
# !ls /
# Out:
# bin	 CS230	  etc	lib32  mnt   root  srv		      tmp    var
# boot	 datalab  home	lib64  opt   run   sys		      tools
# content  dev	  lib	media  proc  sbin  tensorflow-1.15.2  usr

# %%
datafile = np.load("/CS230/ProjectData/train/Lensed/24178.npy")
np.amax(datafile)
# Out:
# 1.5125014509087362

# %% [markdown]
# Visualized Gravitatinal lensing image

# %%
plot_image(datafile,pixel_width=0.08)
print(datafile.shape)
# Out:
# (64, 64)

# %% [markdown]
# Visualization of Training data

# %%
train_url = "/CS230//ProjectData/train/Lensed"

import pathlib

data = pathlib.Path('ProjectData.zip', train_url)
train_images = list(data.glob('*.npy'))

print(train_images[0])
print(len(train_images))

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = np.load(train_images[i]) / 255
    plt.imshow(img, cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    #plt.xlabel(class_names[train_labels[i][0]])
plt.show()
# Out:
# /CS230/ProjectData/train/Lensed/24168.npy
# 20211

# %% [markdown]
# Read Train Images and Train labels. Output layer is 8 continuous parameters

# %%
trainPara = pd.read_csv("/CS230/ProjectData/trainParameters.csv")
#print(trainPara["source_rotation"].dtype)
#display(trainPara)
#print(trainPara.columns)
#trainFeatureName = trainPara["fileName"]
# train_images #/CS230/ProjectData/train/Lensed/52730_5.720406822933091.npy

trainLensedImage = []
trainUnlensedImage = []

for i in tqdm(range(trainPara.shape[0])):
  try:
    img = np.load("/CS230/ProjectData/train/Lensed/"+trainPara['fileName'][i].astype(str)+'.npy')
    label = np.load("/CS230/ProjectData/train/Unlensed/"+trainPara['fileName'][i].astype(str)+'.npy')
    trainLensedImage.append(img)
    trainUnlensedImage.append(label)
  except:
    #continue
    print("/CS230/ProjectData/train/Lensed/"+trainPara['fileName'][i].astype(str))

xTrainLensed = np.array(trainLensedImage)
print(xTrainLensed.shape)
xTrainUnlensed = np.array(trainUnlensedImage)
print(xTrainUnlensed.shape)

#trainLabels = trainPara[['theta_E', 'gamma', 'e1', 'e2','center_x', 'center_y', 'gamma1', 'gamma2']]
##print(trainLabels.head())
#print(trainFeatureName.head())
# Out:
# 100%|██████████| 20211/20211 [00:14<00:00, 1406.99it/s]
# (20211, 64, 64)
# (20211, 64, 64)

# %% [markdown]
# Read Dev Images and Dev labels.

# %%
devPara = pd.read_csv("/CS230/ProjectData/devParameters.csv")
devLensedImage = []
devUnlensedImage = []

for i in tqdm(range(devPara.shape[0])):
  try:
    img = np.load("/CS230/ProjectData/dev/Lensed/"+devPara['fileName'][i].astype(str)+'.npy')
    label = np.load("/CS230/ProjectData/dev/Unlensed/"+devPara['fileName'][i].astype(str)+'.npy')
    devLensedImage.append(img)
    devUnlensedImage.append(label)
  except:
    #continue
    print("/CS230/ProjectData/dev/Lensed/"+devPara['fileName'][i].astype(str))

xDevLensed = np.array(devLensedImage)
print(xDevLensed.shape)
xDevUnlensed = np.array(devUnlensedImage)
print(xDevUnlensed.shape)

#devLabels = devPara[['theta_E', 'gamma', 'e1', 'e2','center_x', 'center_y', 'gamma1', 'gamma2']]
#print(devLabels.head())
# Out:
# 100%|██████████| 1977/1977 [00:01<00:00, 1123.91it/s]
# (1977, 64, 64)
# (1977, 64, 64)

# %% [markdown]
# Read Test Images and Test labels.

# %%
testPara = pd.read_csv("/CS230/ProjectData/testParameters.csv")
testLensedImage = []
testUnlensedImage = []

for i in tqdm(range(testPara.shape[0])):
  try:
    img = np.load("/CS230/ProjectData/test/Lensed/"+testPara['fileName'][i].astype(str)+'.npy')
    label = np.load("/CS230/ProjectData/test/Unlensed/"+testPara['fileName'][i].astype(str)+'.npy')

    testLensedImage.append(img)
    testUnlensedImage.append(label)
  except:
    #continue
    print("/CS230/ProjectData/test/Lensed/"+testPara['fileName'][i].astype(str))

xTestLensed = np.array(testLensedImage)
print(xTestLensed.shape)
xTestUnlensed = np.array(testUnlensedImage)
print(xTestUnlensed.shape)
#testLabels = testPara[['theta_E', 'gamma', 'e1', 'e2','center_x', 'center_y', 'gamma1', 'gamma2']]
#print(testLabels.head())
# Out:
# 100%|██████████| 1992/1992 [00:01<00:00, 1354.47it/s]
# (1992, 64, 64)
# (1992, 64, 64)

# %% [markdown]
# Train Different U-Net Models

# %%
inputs = Input((64, 64, 1))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='linear') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64, 64, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 16)   160         lambda[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 64, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   2320        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 128)    73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 256)    295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 256)    590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 128)    131200      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 256)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 128)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 32)   9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 16)   2064        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 16)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 16)   2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    17          conv2d_17[0][0]
# ==================================================================================================
# Total params: 1,940,817
# Trainable params: 1,940,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
outputs.shape
# Out:
# TensorShape([None, 64, 64, 1])

# %%
inputs = Input((64, 64, 1))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (p2)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='linear') (c9)

model2 = Model(inputs=[inputs], outputs=[outputs])
model2.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 64, 1)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 16)   160         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 16)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 16)   2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 32)   9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 32)   4128        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_4[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   9248        dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 16)   2064        conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_5[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 16)   2320        dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 1)    17          conv2d_26[0][0]
# ==================================================================================================
# Total params: 57,233
# Trainable params: 57,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
inputs = Input((64, 64, 1))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='relu', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='relu', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='relu',  padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (p2)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='relu',  padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='linear') (c9)

model3 = Model(inputs=[inputs], outputs=[outputs])
model3.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 64, 1)    0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 16)   160         lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 16)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 16)   2320        dropout_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 32)   4640        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 32)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   9248        dropout_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 32)   4128        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_6[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 32)   9248        dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 16)   2064        conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_7[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 16)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 16)   2320        dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 1)    17          conv2d_35[0][0]
# ==================================================================================================
# Total params: 57,233
# Trainable params: 57,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
inputs = Input((64, 64, 1))
#s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (inputs)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
c1 = Conv2D(16, (3, 3), padding='same',use_bias=False) (inputs)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3),  padding='same',use_bias=False) (p1)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
c2 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c2)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (p2)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (c3)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), padding='same', use_bias=False) (p3)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
c4 = Conv2D(128, (3, 3), padding='same',use_bias=False) (c4)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), padding='same',use_bias=False) (p4)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)
c5 = Conv2D(256, (3, 3),  padding='same',use_bias=False) (c5)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (u6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (c6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (u7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (c7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (u8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (u9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)
c9 = Conv2D(16, (3, 3), padding='same',use_bias=False) (c9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)

out = Conv2D(1, (1, 1), use_bias=False) (c9)
out = BatchNormalization()(out)
outputs = Activation('linear')(out)

model4 = Model(inputs=[inputs], outputs=[outputs])
model4.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])
model4.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 16)   144         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 16)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 32)   4608        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 32)   9216        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 64)   18432       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 64)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 64)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    73728       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    147456      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 128)    512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 4, 4, 128)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 256)    294912      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 256)    1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 256)    589824      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 256)    1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 8, 8, 128)    131200      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8, 8, 256)    0           conv2d_transpose_8[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    294912      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    147456      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 16, 16, 64)   32832       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_9[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 64)   73728       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 64)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 32)   8224        activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_10[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 32)   18432       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 32)   9216        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 16)   2064        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_11[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 16)   4608        concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 16)   64          conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 16)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 16)   2304        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 16)   64          conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 1)    16          activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 1)    4           conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 1)    0           batch_normalization_18[0][0]
# ==================================================================================================
# Total params: 1,942,868
# Trainable params: 1,939,954
# Non-trainable params: 2,914
# __________________________________________________________________________________________________

# %%
inputs = Input((64, 64, 1))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (s)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
c1 = Conv2D(16, (3, 3), padding='same',use_bias=False) (c1)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3),  padding='same',use_bias=False) (p1)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
c2 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c2)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (p2)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (c3)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), padding='same', use_bias=False) (p3)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
c4 = Conv2D(128, (3, 3), padding='same',use_bias=False) (c4)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), padding='same',use_bias=False) (p4)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)
c5 = Conv2D(256, (3, 3),  padding='same',use_bias=False) (c5)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (u6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (c6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (u7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (c7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (u8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (u9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)
c9 = Conv2D(16, (3, 3), padding='same',use_bias=False) (c9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)

out = Conv2D(1, (1, 1), use_bias=False) (c9)
out = BatchNormalization()(out)
outputs = Activation('linear')(out)
# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model5 = Model(inputs=[inputs], outputs=[outputs])
model5.compile(loss=ssim_loss, optimizer=optimizer, metrics=['mse',ssim_loss])
model5.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 1)    0           input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 16)   144         lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 16)   64          conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 16)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 16)   2304        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 16)   64          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 32, 32, 16)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 32)   4608        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 32)   128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 32)   9216        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 32)   128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 16, 16, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 16, 16, 64)   18432       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 16, 16, 64)   36864       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 64)   256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 8, 8, 64)     0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 128)    73728       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 128)    512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 128)    147456      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 128)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 4, 4, 128)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 4, 4, 256)    294912      max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 256)    1024        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 4, 4, 256)    589824      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 256)    1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 8, 8, 128)    131200      activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 256)    0           conv2d_transpose_12[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 128)    294912      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 128)    512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 128)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 128)    147456      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 128)    512         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 128)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 16, 16, 64)   32832       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_13[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 64)   73728       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 64)   256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 64)   36864       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 64)   256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 32, 32, 32)   8224        activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_14[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 32)   18432       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 32)   128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 32)   9216        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 64, 64, 16)   2064        activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_15[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 64, 16)   4608        concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 16)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 16)   2304        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 16)   64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 16)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 64, 1)    16          activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64, 64, 1)    4           conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 1)    0           batch_normalization_37[0][0]
# ==================================================================================================
# Total params: 1,945,236
# Trainable params: 1,942,290
# Non-trainable params: 2,946
# __________________________________________________________________________________________________

# %%
inputs = Input((64, 64, 1))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (s)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
c1 = Conv2D(16, (3, 3), padding='same',use_bias=False) (c1)
c1 = BatchNormalization()(c1)
c1 = Activation('relu')(c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3),  padding='same',use_bias=False) (p1)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
c2 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c2)
c2 = BatchNormalization()(c2)
c2 = Activation('relu')(c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (p2)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (c3)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
c3 = Conv2D(64, (3, 3), padding='same',use_bias=False) (c3)
c3 = BatchNormalization()(c3)
c3 = Activation('relu')(c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), padding='same', use_bias=False) (p3)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
c4 = Conv2D(128, (3, 3), padding='same',use_bias=False) (c4)
c4 = BatchNormalization()(c4)
c4 = Activation('relu')(c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), padding='same',use_bias=False) (p4)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)
c5 = Conv2D(256, (3, 3),  padding='same',use_bias=False) (c5)
c5 = BatchNormalization()(c5)
c5 = Activation('relu')(c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (u6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)
c6 = Conv2D(128, (3, 3),  padding='same',use_bias=False) (c6)
c6 = BatchNormalization()(c6)
c6 = Activation('relu')(c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (u7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (c7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)
c7 = Conv2D(64, (3, 3),  padding='same',use_bias=False) (c7)
c7 = BatchNormalization()(c7)
c7 = Activation('relu')(c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (u8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)
c8 = Conv2D(32, (3, 3), padding='same',use_bias=False) (c8)
c8 = BatchNormalization()(c8)
c8 = Activation('relu')(c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3),  padding='same',use_bias=False) (u9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)
c9 = Conv2D(16, (3, 3), padding='same',use_bias=False) (c9)
c9 = BatchNormalization()(c9)
c9 = Activation('relu')(c9)

out = Conv2D(1, (1, 1), use_bias=False) (c9)
out = BatchNormalization()(out)
outputs = Activation('linear')(out)
# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model6 = Model(inputs=[inputs], outputs=[outputs])
model6.compile(loss=mse_ssim_loss, optimizer=optimizer, metrics=['mse',ssim_loss,psnr_loss])
model6.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 64, 64, 1)    0           input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 16)   144         lambda_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 64, 16)   64          conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 16)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 64, 16)   2304        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 64, 16)   64          conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 32, 32, 16)   0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 32)   4608        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 32)   128         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 32)   9216        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 32)   128         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 16, 16, 32)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 64)   18432       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 64)   256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 64)   36864       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 64)   256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 64)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 8, 8, 64)     0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 128)    73728       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 128)    512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 128)    147456      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 128)    512         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 128)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 4, 4, 128)    0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 4, 4, 256)    294912      max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 256)    1024        conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 256)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 4, 4, 256)    589824      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 256)    1024        conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 256)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 8, 8, 128)    131200      activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 256)    0           conv2d_transpose_16[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 128)    294912      concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 8, 128)    512         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 128)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 128)    147456      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 16, 16, 64)   32832       activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_17[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 64)   73728       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 64)   256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 64)   36864       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 64)   256         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 16, 16, 64)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 64)   36864       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 16, 16, 64)   256         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 16, 16, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 32, 32, 32)   8224        activation_53[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_18[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 32)   18432       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 32)   128         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 32)   9216        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 32)   128         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 64, 64, 16)   2064        activation_55[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_19[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 64, 64, 16)   4608        concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 16)   64          conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 64, 64, 16)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 64, 64, 16)   2304        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 16)   64          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64, 64, 16)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 64, 64, 1)    16          activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64, 64, 1)    4           conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 64, 64, 1)    0           batch_normalization_58[0][0]
# ==================================================================================================
# Total params: 2,019,476
# Trainable params: 2,016,274
# Non-trainable params: 3,202
# __________________________________________________________________________________________________

# %%
history5 = model5.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 21s 29ms/step - loss: 0.3961 - mse: 0.9142 - ssim_loss: 0.3961 - val_loss: 0.8146 - val_mse: 0.0482 - val_ssim_loss: 0.8146
# Epoch 2/20
# 632/632 [==============================] - 18s 28ms/step - loss: 0.1401 - mse: 0.7834 - ssim_loss: 0.1401 - val_loss: 0.1364 - val_mse: 1.0919 - val_ssim_loss: 0.1365
# Epoch 3/20
# 632/632 [==============================] - 18s 28ms/step - loss: 0.1141 - mse: 0.7651 - ssim_loss: 0.1141 - val_loss: 0.1171 - val_mse: 1.3111 - val_ssim_loss: 0.1171
# Epoch 4/20
# 632/632 [==============================] - 18s 28ms/step - loss: 0.0964 - mse: 0.7577 - ssim_loss: 0.0964 - val_loss: 0.4068 - val_mse: 0.3878 - val_ssim_loss: 0.4066
# Epoch 5/20
# 632/632 [==============================] - 18s 28ms/step - loss: 0.0850 - mse: 0.7551 - ssim_loss: 0.0850 - val_loss: 0.2464 - val_mse: 0.7370 - val_ssim_loss: 0.2464
# Epoch 6/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0763 - mse: 0.7506 - ssim_loss: 0.0763 - val_loss: 0.1530 - val_mse: 9.8345 - val_ssim_loss: 0.1531
# Epoch 7/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0768 - mse: 0.7504 - ssim_loss: 0.0768 - val_loss: 0.1970 - val_mse: 0.0709 - val_ssim_loss: 0.1969
# Epoch 8/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0696 - mse: 0.7472 - ssim_loss: 0.0696 - val_loss: 0.2801 - val_mse: 0.3579 - val_ssim_loss: 0.2799
# Epoch 9/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0668 - mse: 0.7450 - ssim_loss: 0.0668 - val_loss: 0.1084 - val_mse: 1.1238 - val_ssim_loss: 0.1084
# Epoch 10/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0634 - mse: 0.7438 - ssim_loss: 0.0634 - val_loss: 0.2112 - val_mse: 0.6192 - val_ssim_loss: 0.2112
# Epoch 11/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0645 - mse: 0.7430 - ssim_loss: 0.0645 - val_loss: 0.1628 - val_mse: 0.6077 - val_ssim_loss: 0.1628
# Epoch 12/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0607 - mse: 0.7425 - ssim_loss: 0.0607 - val_loss: 0.0909 - val_mse: 2.5042 - val_ssim_loss: 0.0909
# Epoch 13/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0586 - mse: 0.7410 - ssim_loss: 0.0586 - val_loss: 0.0818 - val_mse: 5.1690 - val_ssim_loss: 0.0818
# Epoch 14/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0557 - mse: 0.7411 - ssim_loss: 0.0557 - val_loss: 0.1832 - val_mse: 2.6071 - val_ssim_loss: 0.1831
# Epoch 15/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0557 - mse: 0.7400 - ssim_loss: 0.0557 - val_loss: 0.1882 - val_mse: 0.0218 - val_ssim_loss: 0.1882
# Epoch 16/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0542 - mse: 0.7401 - ssim_loss: 0.0542 - val_loss: 0.1972 - val_mse: 10.5711 - val_ssim_loss: 0.1972
# Epoch 17/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0525 - mse: 0.7393 - ssim_loss: 0.0525 - val_loss: 0.3263 - val_mse: 0.2083 - val_ssim_loss: 0.3262
# Epoch 18/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0526 - mse: 0.7387 - ssim_loss: 0.0526 - val_loss: 0.0692 - val_mse: 2.4627 - val_ssim_loss: 0.0692
# Epoch 19/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0509 - mse: 0.7387 - ssim_loss: 0.0509 - val_loss: 0.1158 - val_mse: 1.7014 - val_ssim_loss: 0.1159
# Epoch 20/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0495 - mse: 0.7383 - ssim_loss: 0.0495 - val_loss: 0.1299 - val_mse: 1.2017 - val_ssim_loss: 0.1298

# %% [markdown]
# Reshape data

# %%
x_train = xTrainLensed.reshape(-1,64, 64, 1)
x_trainLabel = xTrainUnlensed.reshape(-1,64, 64, 1)

x_dev = xDevLensed.reshape(-1, 64, 64, 1)
x_devLabel = xDevUnlensed.reshape(-1, 64, 64, 1)

x_test = xTestLensed.reshape(-1, 64, 64, 1)
x_testLabel = xTestUnlensed.reshape(-1, 64, 64, 1)

# %%
compare_images(x_dev[1],x_dev[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/metrics/simple_metrics.py:160: RuntimeWarning: divide by zero encountered in double_scalars
#   return 10 * np.log10((data_range ** 2) / err)
# [inf, 0.0, 1.0]

# %%
history6 = model6.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 74s 34ms/step - loss: 0.9567 - mse: 0.5161 - ssim_loss: 0.4406 - psnr_loss: 10.7725 - val_loss: 0.6917 - val_mse: 0.0271 - val_ssim_loss: 0.6645 - val_psnr_loss: 20.7271
# Epoch 2/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.2140 - mse: 0.0890 - ssim_loss: 0.1249 - psnr_loss: 18.4624 - val_loss: 0.1624 - val_mse: 0.0383 - val_ssim_loss: 0.1241 - val_psnr_loss: 22.3420
# Epoch 3/20
# 632/632 [==============================] - 19s 29ms/step - loss: 0.1090 - mse: 0.0123 - ssim_loss: 0.0967 - psnr_loss: 24.8308 - val_loss: 0.1321 - val_mse: 0.0057 - val_ssim_loss: 0.1265 - val_psnr_loss: 26.0495
# Epoch 4/20
# 632/632 [==============================] - 19s 29ms/step - loss: 0.0835 - mse: 0.0050 - ssim_loss: 0.0784 - psnr_loss: 27.8755 - val_loss: 0.0803 - val_mse: 0.0031 - val_ssim_loss: 0.0772 - val_psnr_loss: 29.3004
# Epoch 5/20
# 632/632 [==============================] - 19s 29ms/step - loss: 0.0752 - mse: 0.0047 - ssim_loss: 0.0705 - psnr_loss: 28.6027 - val_loss: 0.3049 - val_mse: 0.0033 - val_ssim_loss: 0.3016 - val_psnr_loss: 28.0637
# Epoch 6/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0707 - mse: 0.0043 - ssim_loss: 0.0664 - psnr_loss: 29.0839 - val_loss: 0.1334 - val_mse: 0.0032 - val_ssim_loss: 0.1303 - val_psnr_loss: 28.9955
# Epoch 7/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0676 - mse: 0.0042 - ssim_loss: 0.0634 - psnr_loss: 29.1251 - val_loss: 0.0941 - val_mse: 0.0033 - val_ssim_loss: 0.0909 - val_psnr_loss: 27.8454
# Epoch 8/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0641 - mse: 0.0040 - ssim_loss: 0.0601 - psnr_loss: 29.4420 - val_loss: 0.0770 - val_mse: 0.0028 - val_ssim_loss: 0.0742 - val_psnr_loss: 29.9398
# Epoch 9/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0610 - mse: 0.0036 - ssim_loss: 0.0574 - psnr_loss: 29.5374 - val_loss: 0.1100 - val_mse: 0.0037 - val_ssim_loss: 0.1064 - val_psnr_loss: 27.4614
# Epoch 10/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0599 - mse: 0.0036 - ssim_loss: 0.0562 - psnr_loss: 29.7690 - val_loss: 0.0625 - val_mse: 0.0025 - val_ssim_loss: 0.0600 - val_psnr_loss: 30.2201
# Epoch 11/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0570 - mse: 0.0033 - ssim_loss: 0.0537 - psnr_loss: 29.9080 - val_loss: 0.0884 - val_mse: 0.0028 - val_ssim_loss: 0.0856 - val_psnr_loss: 29.0563
# Epoch 12/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0551 - mse: 0.0034 - ssim_loss: 0.0518 - psnr_loss: 29.9941 - val_loss: 0.1003 - val_mse: 0.0029 - val_ssim_loss: 0.0974 - val_psnr_loss: 29.0294
# Epoch 13/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0555 - mse: 0.0035 - ssim_loss: 0.0520 - psnr_loss: 30.2162 - val_loss: 0.3598 - val_mse: 0.0028 - val_ssim_loss: 0.3569 - val_psnr_loss: 28.2014
# Epoch 14/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0537 - mse: 0.0032 - ssim_loss: 0.0505 - psnr_loss: 30.2968 - val_loss: 0.1665 - val_mse: 0.0025 - val_ssim_loss: 0.1639 - val_psnr_loss: 29.2054
# Epoch 15/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0504 - mse: 0.0029 - ssim_loss: 0.0475 - psnr_loss: 30.4999 - val_loss: 0.1228 - val_mse: 0.0025 - val_ssim_loss: 0.1203 - val_psnr_loss: 29.6976
# Epoch 16/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0486 - mse: 0.0028 - ssim_loss: 0.0458 - psnr_loss: 30.7250 - val_loss: 0.1566 - val_mse: 0.0060 - val_ssim_loss: 0.1505 - val_psnr_loss: 25.5248
# Epoch 17/20
# 632/632 [==============================] - 19s 30ms/step - loss: 0.0471 - mse: 0.0028 - ssim_loss: 0.0443 - psnr_loss: 30.7774 - val_loss: 0.0704 - val_mse: 0.0057 - val_ssim_loss: 0.0647 - val_psnr_loss: 26.1810
# Epoch 18/20
# 632/632 [==============================] - 19s 29ms/step - loss: 0.0468 - mse: 0.0029 - ssim_loss: 0.0440 - psnr_loss: 30.7807 - val_loss: 0.0486 - val_mse: 0.0017 - val_ssim_loss: 0.0470 - val_psnr_loss: 32.1515
# Epoch 19/20
# 632/632 [==============================] - 19s 29ms/step - loss: 0.0463 - mse: 0.0027 - ssim_loss: 0.0435 - psnr_loss: 30.6117 - val_loss: 0.2004 - val_mse: 0.0025 - val_ssim_loss: 0.1979 - val_psnr_loss: 29.4184
# Epoch 20/20
# 632/632 [==============================] - 18s 29ms/step - loss: 0.0444 - mse: 0.0029 - ssim_loss: 0.0415 - psnr_loss: 30.8162 - val_loss: 0.1178 - val_mse: 0.0018 - val_ssim_loss: 0.1160 - val_psnr_loss: 30.8468

# %%
history1 = model.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 50s 25ms/step - loss: 0.0128 - mse: 0.0128 - mae: 0.0385 - mape: 5692942.7066 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0258 - val_mape: 4720977.0000
# Epoch 2/20
# 632/632 [==============================] - 14s 23ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0235 - mape: 2726411.7733 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0184 - val_mape: 2353529.7500
# Epoch 3/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0218 - mape: 2262169.5122 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0174 - val_mape: 1181603.6250
# Epoch 4/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0201 - mape: 1935761.3154 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0160 - val_mape: 835282.9375
# Epoch 5/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0195 - mape: 1875937.4240 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0336 - val_mape: 8158973.5000
# Epoch 6/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0200 - mape: 1960347.4056 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0168 - val_mape: 1568280.8750
# Epoch 7/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0185 - mape: 1642906.1170 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0202 - val_mape: 3518098.5000
# Epoch 8/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0190 - mape: 1831551.8622 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0179 - val_mape: 2064812.1250
# Epoch 9/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0157 - mse: 0.0157 - mae: 0.0300 - mape: 3605762.1993 - val_loss: 0.0161 - val_mse: 0.0161 - val_mae: 0.0278 - val_mape: 2852514.5000
# Epoch 10/20
# 632/632 [==============================] - 15s 23ms/step - loss: 0.0189 - mse: 0.0189 - mae: 0.0340 - mape: 4155665.6402 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.0288 - val_mape: 3881337.7500
# Epoch 11/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0167 - mse: 0.0167 - mae: 0.0311 - mape: 3722864.8780 - val_loss: 0.0134 - val_mse: 0.0134 - val_mae: 0.0316 - val_mape: 5910411.0000
# Epoch 12/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0154 - mse: 0.0154 - mae: 0.0292 - mape: 3248792.6943 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0244 - val_mape: 1581641.6250
# Epoch 13/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0148 - mse: 0.0148 - mae: 0.0282 - mape: 3025900.2401 - val_loss: 0.0121 - val_mse: 0.0121 - val_mae: 0.0343 - val_mape: 7179255.0000
# Epoch 14/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0148 - mse: 0.0148 - mae: 0.0282 - mape: 3217666.7255 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0230 - val_mape: 2270981.2500
# Epoch 15/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0138 - mse: 0.0138 - mae: 0.0273 - mape: 3002486.3369 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0209 - val_mape: 1139223.1250
# Epoch 16/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0134 - mse: 0.0134 - mae: 0.0262 - mape: 2705692.3460 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0314 - val_mape: 5311670.0000
# Epoch 17/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0270 - mape: 2990082.3791 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0209 - val_mape: 941737.2500
# Epoch 18/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0124 - mse: 0.0124 - mae: 0.0262 - mape: 2827183.9722 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0214 - val_mape: 1555499.5000
# Epoch 19/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0122 - mse: 0.0122 - mae: 0.0253 - mape: 2523943.2642 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0195 - val_mape: 1036152.8750
# Epoch 20/20
# 632/632 [==============================] - 15s 24ms/step - loss: 0.0113 - mse: 0.0113 - mae: 0.0248 - mape: 2451876.3148 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0268 - val_mape: 4067529.0000

# %% [markdown]
# Compile and train the model

# %%
#model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])

history2 = model2.fit(x_train, x_trainLabel,batch_size=32, epochs=5, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/5
# 632/632 [==============================] - 57s 19ms/step - loss: 0.0316 - mse: 0.0316 - mae: 0.0523 - mape: 7481404.2943 - val_loss: 0.0173 - val_mse: 0.0173 - val_mae: 0.0329 - val_mape: 4128922.7500
# Epoch 2/5
# 632/632 [==============================] - 11s 17ms/step - loss: 0.0210 - mse: 0.0210 - mae: 0.0381 - mape: 5338696.3100 - val_loss: 0.0146 - val_mse: 0.0146 - val_mae: 0.0373 - val_mape: 6033246.0000
# Epoch 3/5
# 632/632 [==============================] - 11s 18ms/step - loss: 0.0175 - mse: 0.0175 - mae: 0.0350 - mape: 4856519.0616 - val_loss: 0.0131 - val_mse: 0.0131 - val_mae: 0.0254 - val_mape: 2421344.0000
# Epoch 4/5
# 632/632 [==============================] - 11s 18ms/step - loss: 0.0163 - mse: 0.0163 - mae: 0.0326 - mape: 4198654.6726 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0278 - val_mape: 4602878.0000
# Epoch 5/5
# 632/632 [==============================] - 11s 18ms/step - loss: 0.0144 - mse: 0.0144 - mae: 0.0309 - mape: 3980636.7998 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0248 - val_mape: 2343511.0000

# %%
history3 = model3.fit(x_train, x_trainLabel,batch_size=32, epochs=10, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/10
# 632/632 [==============================] - 12s 17ms/step - loss: 0.0306 - mse: 0.0306 - mae: 0.0413 - mape: 5264455.6295 - val_loss: 0.0152 - val_mse: 0.0152 - val_mae: 0.0244 - val_mape: 1254766.7500
# Epoch 2/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0185 - mse: 0.0185 - mae: 0.0277 - mape: 1711942.6390 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0279 - val_mape: 2815963.2500
# Epoch 3/10
# 632/632 [==============================] - 10s 17ms/step - loss: 0.0159 - mse: 0.0159 - mae: 0.0261 - mape: 1552686.8584 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0228 - val_mape: 1541281.7500
# Epoch 4/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0145 - mse: 0.0145 - mae: 0.0250 - mape: 1418443.7075 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0212 - val_mape: 996074.3125
# Epoch 5/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0142 - mse: 0.0142 - mae: 0.0247 - mape: 1518394.0963 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0217 - val_mape: 1601004.0000
# Epoch 6/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0134 - mse: 0.0134 - mae: 0.0240 - mape: 1473652.5970 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0238 - val_mape: 2239396.5000
# Epoch 7/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0238 - mape: 1375739.8290 - val_loss: 0.0104 - val_mse: 0.0104 - val_mae: 0.0203 - val_mape: 480676.8125
# Epoch 8/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0126 - mse: 0.0126 - mae: 0.0236 - mape: 1428178.8325 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0204 - val_mape: 520856.9062
# Epoch 9/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0121 - mse: 0.0121 - mae: 0.0239 - mape: 1589272.7533 - val_loss: 0.0104 - val_mse: 0.0104 - val_mae: 0.0211 - val_mape: 1492661.0000
# Epoch 10/10
# 632/632 [==============================] - 10s 16ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0234 - mape: 1458702.1736 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0214 - val_mape: 1593813.7500

# %%
history4 = model4.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 9s 13ms/step - loss: 0.0508 - mse: 0.0508 - mae: 0.0748 - mape: 11655441.3025 - val_loss: 0.0150 - val_mse: 0.0150 - val_mae: 0.0393 - val_mape: 7038860.5000
# Epoch 2/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0177 - mse: 0.0177 - mae: 0.0359 - mape: 4627052.4581 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.0542 - val_mape: 12988696.0000
# Epoch 3/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0151 - mse: 0.0151 - mae: 0.0321 - mape: 3939918.9775 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.0474 - val_mape: 9016083.0000
# Epoch 4/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0131 - mse: 0.0131 - mae: 0.0297 - mape: 3389232.7200 - val_loss: 0.0112 - val_mse: 0.0112 - val_mae: 0.0306 - val_mape: 4472354.0000
# Epoch 5/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0115 - mse: 0.0115 - mae: 0.0277 - mape: 3050947.5221 - val_loss: 0.0121 - val_mse: 0.0121 - val_mae: 0.0282 - val_mape: 3931229.5000
# Epoch 6/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0270 - mape: 3075934.8570 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0241 - val_mape: 2795821.2500
# Epoch 7/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0262 - mape: 2984625.5355 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0252 - val_mape: 3519923.2500
# Epoch 8/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0259 - mape: 3029395.4941 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0270 - val_mape: 4053935.2500
# Epoch 9/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0248 - mape: 2761180.1351 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0280 - val_mape: 3563666.7500
# Epoch 10/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0251 - mape: 2919331.5486 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0268 - val_mape: 4391149.5000
# Epoch 11/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0248 - mape: 2863695.3085 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0244 - val_mape: 3477971.2500
# Epoch 12/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0239 - mape: 2667241.9305 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0250 - val_mape: 3981115.7500
# Epoch 13/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0236 - mape: 2597292.8886 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0224 - val_mape: 2544280.2500
# Epoch 14/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0228 - mape: 2439287.5571 - val_loss: 0.0164 - val_mse: 0.0164 - val_mae: 0.0405 - val_mape: 7257207.0000
# Epoch 15/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0237 - mape: 2803566.3377 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0306 - val_mape: 5022424.0000
# Epoch 16/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0224 - mape: 2504334.8466 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0254 - val_mape: 4867769.0000
# Epoch 17/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0218 - mape: 2382175.5241 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0253 - val_mape: 4092165.5000
# Epoch 18/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0217 - mape: 2268495.1570 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0274 - val_mape: 5442481.5000
# Epoch 19/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0229 - mape: 2765010.6288 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0193 - val_mape: 1847458.6250
# Epoch 20/20
# 632/632 [==============================] - 8s 12ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0216 - mape: 2341833.8108 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0241 - val_mape: 2905344.5000

# %%
history4 = model4.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 14s 20ms/step - loss: 0.0229 - mse: 0.0229 - mae: 0.0440 - mape: 5845833.0296 - val_loss: 0.0216 - val_mse: 0.0216 - val_mae: 0.0275 - val_mape: 2870211.0000
# Epoch 2/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0196 - mape: 1697396.4706 - val_loss: 0.0141 - val_mse: 0.0141 - val_mae: 0.0216 - val_mape: 1484499.5000
# Epoch 3/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0169 - mape: 1026282.5646 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0208 - val_mape: 1647871.3750
# Epoch 4/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0162 - mape: 993176.4106 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0172 - val_mape: 1474812.5000
# Epoch 5/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0160 - mape: 1052273.6203 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0175 - val_mape: 1875424.5000
# Epoch 6/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0153 - mape: 993292.0160 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0208 - val_mape: 3541423.7500
# Epoch 7/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0145 - mape: 982526.1876 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0202 - val_mape: 2420594.2500
# Epoch 8/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0141 - mape: 985051.1220 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0149 - val_mape: 1231672.5000
# Epoch 9/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0137 - mape: 1010897.4771 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0226 - val_mape: 6033407.0000
# Epoch 10/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0135 - mape: 982604.8883 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0184 - val_mape: 4151185.2500
# Epoch 11/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0134 - mape: 1043749.5771 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0131 - val_mape: 1484607.6250
# Epoch 12/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0131 - mape: 1005523.6005 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0214 - val_mape: 6196685.0000
# Epoch 13/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0128 - mape: 959495.3886 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0184 - val_mape: 4122478.7500
# Epoch 14/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0126 - mape: 1022634.6172 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0138 - val_mape: 1767597.2500
# Epoch 15/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0124 - mape: 914983.2900 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0153 - val_mape: 752559.5625
# Epoch 16/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0122 - mape: 940451.3040 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0111 - val_mape: 600036.8750
# Epoch 17/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0120 - mape: 865904.6736 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0273 - val_mape: 7041772.0000
# Epoch 18/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0122 - mape: 960908.8474 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0122 - val_mape: 777532.6875
# Epoch 19/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0118 - mape: 853334.3703 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0136 - val_mape: 1240949.5000
# Epoch 20/20
# 632/632 [==============================] - 12s 19ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0116 - mape: 909514.3874 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0157 - val_mape: 3724171.5000

# %%
historyT = model4.fit(x_train, x_trainLabel,batch_size=32, epochs=20, validation_data=(x_dev, x_devLabel))
# Out:
# Epoch 1/20
# 632/632 [==============================] - 23s 24ms/step - loss: 0.4875 - mse: 0.4875 - mae: 0.1983 - mape: 41117599.6682 - val_loss: 0.1051 - val_mse: 0.1051 - val_mae: 0.0776 - val_mape: 16083929.0000
# Epoch 2/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0627 - mse: 0.0627 - mae: 0.0664 - mape: 12662604.2180 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0197 - val_mape: 2339396.7500
# Epoch 3/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0208 - mape: 2469975.2934 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0137 - val_mape: 638975.4375
# Epoch 4/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0152 - mape: 1036401.8681 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0185 - val_mape: 1004340.6250
# Epoch 5/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0150 - mape: 977471.8098 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0284 - val_mape: 713491.6250
# Epoch 6/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0146 - mape: 1056621.0262 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0137 - val_mape: 491122.5312
# Epoch 7/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0143 - mape: 1034624.9926 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0129 - val_mape: 924010.0625
# Epoch 8/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0140 - mape: 1013350.4159 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0129 - val_mape: 581727.0000
# Epoch 9/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0137 - mape: 1060803.7151 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0117 - val_mape: 569799.9375
# Epoch 10/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0132 - mape: 1005242.8468 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0143 - val_mape: 1635217.2500
# Epoch 11/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0131 - mape: 975032.2095 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0144 - val_mape: 1197910.2500
# Epoch 12/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0134 - mape: 1023115.5568 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0112 - val_mape: 719187.3125
# Epoch 13/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0124 - mape: 909523.8491 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0153 - val_mape: 1539968.5000
# Epoch 14/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0128 - mape: 1072299.6588 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0166 - val_mape: 789525.4375
# Epoch 15/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0123 - mape: 906868.7377 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0118 - val_mape: 375641.5625
# Epoch 16/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0122 - mape: 1009240.0116 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0110 - val_mape: 521085.4062
# Epoch 17/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0120 - mape: 1027394.3240 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0119 - val_mape: 520323.6875
# Epoch 18/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0119 - mape: 955566.8810 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0156 - val_mape: 530256.9375
# Epoch 19/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0119 - mape: 1009633.1248 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0110 - val_mape: 446405.4062
# Epoch 20/20
# 632/632 [==============================] - 14s 22ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0116 - mape: 958374.2688 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0103 - val_mape: 475606.0625

# %%
# !pip install numpy==1.19.5
# Out:
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
test_results = model6.predict(x_test)

# %%
test_results.shape
# Out:
# (1992, 64, 64, 1)

# %%
id =2
pred =(np.squeeze(test_results[id]))
lab =(np.squeeze(x_testLabel[id]))

img =(np.squeeze(x_test[id]))

# %%
plot_image(lab,pixel_width=0.08)
#plot_image(pred,pixel_width=0.08)

print((np.squeeze(test_results[id])).shape)
# Out:
# (64, 64)

# %%
plot_image(pred,pixel_width=0.08)

# %%
 for i in range(30):
   plot = True
   if plot:
     f, axes = plt.subplots(ncols=3, figsize=(12, 4))
     lensed= np.squeeze(x_test[i])
     label = np.squeeze(x_testLabel[i])  
     pred = np.squeeze(test_results[i])
     plt.sca(axes[0])
     plot_image(lensed,pixel_width=0.08)
     plt.title("Lensed")
        
     plt.sca(axes[1])
     plot_image(label,pixel_width=0.08)
     plt.title("Label")

     plt.sca(axes[-1])
     plot_image(pred,pixel_width=0.08)
     plt.title("Genrated")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
img = Image.open('gl.jpg').convert('L')
img = img.resize((64, 64), Image.ANTIALIAS)
pic1 = np.array(img)
pic.shape
pic =  pic1.reshape(-1, 64, 64, 1)
pic.shape
img

# %%
picresult = model6.predict(pic/255)
id =2
pred =(np.squeeze(picresult))

img =(np.squeeze(pic))
plot_image(pred,pixel_width=0.08)

# %%
plt.imshow(pic1/255, cmap='gray',clim=(0,1))

# %%
plt.imshow(pred, cmap='gray',clim=(0,1))

# %%
plot_image(pic1/255,pixel_width=0.08)

# %%
# Plotting both resukt vs original in same view  
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = np.squeeze(test_results[i])
    plt.imshow(img, cmap='gray',clim=(0,1))


    plt1.subplot(5,3,i+1)
    plt1.xticks([])
    plt1.yticks([])
    plt1.grid(False)
    label = np.squeeze(x_testLabel[i])
    plt1.imshow(label, cmap='gray',clim=(0,1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-321392731320> in <module>()
#      10
#      11
# ---> 12     plt1.subplot(5,3,i+1)
#      13     plt1.xticks([])
#      14     plt1.yticks([])
#
# NameError: name 'plt1' is not defined

# %% [markdown]
# Visualize  results
# Create plots of loss on the training and validation sets.

# %%
# Get training and test loss histories
training_loss = history.history['loss']
dev_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, dev_loss, 'b-')
plt.legend(['Training Loss', 'Dev Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2e84db4eefa9> in <module>()
#       1 # Get training and test loss histories
# ----> 2 training_loss = history.history['loss']
#       3 dev_loss = history.history['val_loss']
#       4
#       5 # Create count of the number of epochs
#
# NameError: name 'history' is not defined

# %%
# plot metrics
from matplotlib import pyplot
pyplot.plot(history.history['mse'])

pyplot.show()

# %%
pyplot.plot(history.history['mae'])
pyplot.show()

# %%
pyplot.plot(history.history['mape'])
pyplot.show()

# %% [markdown]
# Analyze test results per output class
